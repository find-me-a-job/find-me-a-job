# %%
import pickle
import pandas as pd

# %%
with open("data", "rb") as fp:   # Unpickling
    data = pickle.load(fp)

# %%
df = pd.DataFrame(data, columns=['Job Title', 'Skills', 'Link', 'Salary', 'Type'])

# %%
def convert_and_return_avg_in_lakhs(value):
# function that extract value from salary string and return the average in LPA

    
    try:
        #for range which has both thousands and lacks
        if ',' in value and ('Lac' in value or 'Lacs' in value):
            value = value.replace(',', '') #str
            value=value.split(" ")[0] #str
            value = value.split("-") #arr of str
            temp = 0
            for i in value:
                i=float(i)
                if i > 1000:
                    i=i/100000
                temp += float(i)
            value = temp/2
            return value 
        
        # for range which has only thousands
        elif ',' in value:
            
            value = value.replace(',', '') #str
            value=value.split(" ")[0] #str
            
            if "-" in value: 
                value = value.split("-") #arr of str
                temp = 0
                for i in value:
                    i=float(i)
                    i= i/100000
                    temp += i
                value = temp/2
                return value
            else:
                value = float(value)
                value = value/100000
                return value
        # values that has lacs and crores     
        elif 'Cr' in value and ('Lac' in value or 'Lacs' in value):
            value = value.replace(' Lacs', '').replace(' Lac', '').replace(' Cr', "")
            value = value.split(" ")[0]
            value = value.split("-")
            temp = 0
            for i in range(len(value)):
                value[i]=float(value[i])
                if i == 1:
                    value[i]=value[i]*100
                temp += value[i]
            value = temp/2
            return value
        # values that has range in crores
        elif 'Cr' in value:
            value=value.split(" ")[0] #str
            if "-" in value: 
                value = value.split("-") #arr of str
                temp = 0
                for i in value:
                    i=float(i)
                    i=i*100
                    temp += i
                value = temp/2
                return value
            else:
                value = float(value)
                return value
        # for lacs    
        elif 'Lac' in value or 'Lacs' in value:
            
            value=value.split(" ")[0] #str
            if "-" in value: 
                value = value.split("-") #arr of str
                temp = 0
                for i in value:
                    i=float(i)
                    temp += i
                value = temp/2
                return value
            else:
                value = float(value)
                return value
        else:
            return None
    except:
            return value

# %%
# creates a new column in the dataframe where it stores the average salary in lacks
df['Average Salary (Lacs PA)'] = df['Salary'].apply(convert_and_return_avg_in_lakhs)

# %%
# it only consiters the numeric and replace rest with None and then it calculates the mean salary or average salary
average_salary = pd.to_numeric(df["Average Salary (Lacs PA)"], errors='coerce').mean()

# %%
#extracting skills
skills={}
def extracting_skills(value):
    arr = value
    for skill in arr:
        if skill in skills:
            skills[skill]+=1
        else:
            skills[skill]=1

# %%
df["Skills"].apply(extracting_skills)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 25073    None
# 25074    None
# 25075    None
# 25076    None
# 25077    None
# Name: Skills, Length: 25078, dtype: object

# %%
#sorting the skill dictionary in decresing order to frequency of the skills
sorted_skills = dict(sorted(skills.items(), key=lambda item: item[1], reverse=True))

# %%
sorted_skills
# Out:
# {'data analysis': 8650,
#  'analytical': 3218,
#  'machine learning': 3060,
#  'python': 2878,
#  'sql': 2357,
#  'project management': 2316,
#  'business analysis': 1733,
#  'analytics': 1674,
#  'management': 1666,
#  'agile': 1610,
#  'data science': 1514,
#  'computer science': 1434,
#  'data management': 1362,
#  'business analyst': 1361,
#  'automation': 1338,
#  'data': 1314,
#  'data modeling': 1220,
#  'power bi': 1178,
#  'consulting': 1071,
#  'data analytics': 995,
#  'healthcare': 991,
#  'coding': 990,
#  'business intelligence': 990,
#  'data quality': 964,
#  'excel': 945,
#  'market research': 884,
#  'artificial intelligence': 877,
#  'natural language processing': 861,
#  'operations': 828,
#  'data visualization': 796,
#  'customer service': 768,
#  'javascript': 758,
#  'troubleshooting': 719,
#  'data mining': 716,
#  'c++': 701,
#  'sales': 694,
#  'analytical skills': 676,
#  'manager technology': 674,
#  'analysis': 670,
#  'research': 661,
#  'html': 652,
#  'sap': 652,
#  'oracle': 634,
#  'social media': 626,
#  'monitoring': 621,
#  'deep learning': 618,
#  'information technology': 617,
#  'mysql': 609,
#  'data collection': 608,
#  'product management': 583,
#  'process improvement': 574,
#  'training': 569,
#  'tableau': 566,
#  'microsoft': 563,
#  'gcp': 561,
#  'data processing': 549,
#  'aws': 548,
#  'data warehousing': 548,
#  'data structures': 536,
#  'linux': 535,
#  'forecasting': 520,
#  'cloud': 517,
#  'data analyst': 513,
#  'ms office': 508,
#  'risk management': 505,
#  'manager quality assurance': 504,
#  'programming': 496,
#  'digital marketing': 487,
#  'sas': 484,
#  'interpersonal skills': 473,
#  'mis': 472,
#  'networking': 468,
#  'supply chain': 466,
#  'development': 463,
#  'finance': 437,
#  'continuous improvement': 434,
#  'business analytics': 424,
#  'erp': 424,
#  'statistics': 419,
#  'debugging': 418,
#  'spark': 414,
#  'data engineering': 413,
#  'algorithms': 408,
#  'image processing': 407,
#  'team management': 400,
#  'jira': 393,
#  'application development': 386,
#  'architecture': 378,
#  'microsoft azure': 376,
#  'scrum': 375,
#  'usage': 369,
#  'git': 368,
#  'customer relationship': 367,
#  'big data': 360,
#  'bi': 355,
#  'google analytics': 354,
#  'java': 351,
#  'chatbot': 342,
#  'financial analysis': 340,
#  'financial services': 337,
#  'computer vision': 334,
#  'asset management': 333,
#  'front end': 331,
#  'change management': 330,
#  'scala': 329,
#  'advanced excel': 328,
#  'performance tuning': 323,
#  'pyspark': 321,
#  'backend': 321,
#  'san': 320,
#  'ssis': 314,
#  'procurement': 313,
#  'strategic planning': 312,
#  'help desk': 310,
#  'access controls': 310,
#  'database design': 306,
#  'open source': 306,
#  'business process': 306,
#  'telephony support': 305,
#  'crm': 304,
#  'cloud computing': 304,
#  'mis reporting': 304,
#  'gap analysis': 303,
#  'xml': 301,
#  'pharma': 299,
#  'presentation skills': 295,
#  'stakeholder management': 295,
#  'seo': 293,
#  'hive': 288,
#  'scheduling': 288,
#  'macros': 285,
#  'workflow': 277,
#  'administration': 276,
#  'nosql': 274,
#  'compliance': 270,
#  'etl': 269,
#  'accounting': 269,
#  'data migration': 265,
#  'informatica': 264,
#  'budgeting': 262,
#  'data governance': 259,
#  'neural networks': 256,
#  'business solutions': 252,
#  'marketing': 251,
#  'unix': 251,
#  'communication skills': 251,
#  'machine': 250,
#  'tensorflow': 248,
#  'postgresql': 241,
#  'data security': 240,
#  'rdbms': 240,
#  'css': 239,
#  'software testing': 236,
#  'r': 235,
#  'it services': 235,
#  'hadoop': 234,
#  'machine learning algorithms': 230,
#  'vendor management': 227,
#  'science': 225,
#  'pdf': 220,
#  'ms sql': 219,
#  'predictive modeling': 213,
#  'time management': 212,
#  'stored procedures': 210,
#  'sql queries': 209,
#  'hr': 209,
#  'business strategy': 208,
#  'database': 207,
#  'data validation': 207,
#  'version control': 207,
#  'deployment': 206,
#  'health insurance': 203,
#  'senior': 201,
#  'billing': 200,
#  'test cases': 200,
#  'manager quality control': 199,
#  'apache': 198,
#  'web development': 196,
#  'software development life cycle': 194,
#  'jquery': 194,
#  'business development': 193,
#  'agile methodology': 193,
#  'web technologies': 188,
#  'pytorch': 187,
#  'reconciliation': 187,
#  'metadata': 186,
#  'staffing': 185,
#  'financial reporting': 185,
#  'modeling': 181,
#  'reporting': 181,
#  'banking': 180,
#  'lead generation': 179,
#  'unit testing': 178,
#  'payroll': 178,
#  'publishing': 178,
#  'snowflake': 176,
#  'performance management': 175,
#  'technical support': 173,
#  'azure': 172,
#  'customer support': 172,
#  'simulation': 171,
#  'windows': 171,
#  'email marketing': 171,
#  'life sciences': 170,
#  'devops': 170,
#  'data integrity': 167,
#  'e-commerce': 166,
#  'ssrs': 166,
#  'django': 166,
#  'project planning': 165,
#  'supply chain management': 165,
#  'system design': 165,
#  'information': 165,
#  'ml': 164,
#  'testing': 164,
#  'data cleansing': 164,
#  'sdlc': 164,
#  'php': 163,
#  'career development': 162,
#  'web analytics': 162,
#  'financial planning': 162,
#  'documentation': 161,
#  'analyst': 160,
#  'spss': 158,
#  'dbms': 158,
#  'json': 158,
#  'c#': 157,
#  'record to report': 157,
#  'process': 155,
#  'senior analyst': 154,
#  'statistical analysis': 154,
#  'relationship management': 154,
#  'nlp': 152,
#  'plsql': 152,
#  'software development': 152,
#  'report generation': 150,
#  'vlookup': 147,
#  'shell scripting': 146,
#  'reporting analysis': 146,
#  'engineering': 145,
#  'marketing campaigns': 145,
#  'soc': 145,
#  'qlikview': 144,
#  'mathematics': 144,
#  'prototype': 144,
#  'mongodb': 143,
#  'infrastructure': 143,
#  'account management': 142,
#  'intelligence': 140,
#  'packaging': 138,
#  'telecom': 138,
#  'operations research': 138,
#  'data munging': 138,
#  'statistical modeling': 135,
#  'focus': 135,
#  'sem': 135,
#  'matlab': 134,
#  'project delivery': 134,
#  'powerpoint': 134,
#  'risk assessment': 133,
#  'customer experience': 133,
#  'claims': 132,
#  'investment banking': 130,
#  'product engineering': 129,
#  'relationship building': 128,
#  'information security': 128,
#  'management consulting': 127,
#  'requirement gathering': 126,
#  'iso': 126,
#  'operations management': 126,
#  'software': 125,
#  'software design': 125,
#  'presales': 125,
#  'recruitment': 124,
#  'bfsi': 123,
#  'http': 123,
#  'market analysis': 123,
#  'business administration': 123,
#  'talent acquisition': 123,
#  'advanced analytics': 122,
#  'sales operations': 122,
#  'medical insurance': 121,
#  'journal entries': 121,
#  'github': 120,
#  'brand awareness': 120,
#  'wellness': 119,
#  'production support': 117,
#  'data architecture': 115,
#  'data extraction': 115,
#  'azure data factory': 115,
#  'diversity and inclusion': 115,
#  'schema': 112,
#  'product design': 111,
#  'problem solving': 111,
#  'pmp': 110,
#  'operational excellence': 109,
#  'competitive analysis': 108,
#  'hiring': 108,
#  'sales process': 108,
#  'root cause analysis': 107,
#  'retail': 107,
#  'visio': 107,
#  'scikit-learn': 106,
#  'technical writing': 106,
#  'c': 106,
#  'ppc': 106,
#  'process design': 105,
#  'dashboards': 104,
#  'hlookup': 104,
#  'sales strategy': 104,
#  'microsoft power bi': 103,
#  'basic': 102,
#  'online marketing': 102,
#  'mining': 101,
#  'data privacy': 101,
#  'vba': 101,
#  'business requirement analysis': 101,
#  'distribution system': 101,
#  'adobe': 101,
#  'data mapping': 100,
#  'user stories': 100,
#  'social media marketing': 100,
#  'advertising': 98,
#  'back office': 98,
#  'query': 98,
#  'user acceptance testing': 98,
#  'assistance': 97,
#  'process automation': 96,
#  'technical': 96,
#  'sms': 96,
#  'campaign management': 96,
#  'salesforce': 96,
#  'ms access': 95,
#  'renewable energy': 95,
#  'auditing': 95,
#  'business planning': 94,
#  'sql server': 93,
#  'microstrategy': 92,
#  'due diligence': 92,
#  'python development': 92,
#  'azure databricks': 91,
#  'report writing': 91,
#  'system architecture': 90,
#  'project': 90,
#  'bpo': 89,
#  'assurance': 89,
#  'content management': 89,
#  'data manipulation': 88,
#  'orchestration': 88,
#  'gaming': 88,
#  'media': 88,
#  'olap': 87,
#  'underwriting': 87,
#  'customer acquisition': 87,
#  'web services': 87,
#  'data scientist': 86,
#  'data bricks': 86,
#  'taxation': 86,
#  'equity': 86,
#  'solution architecture': 86,
#  'bigquery': 86,
#  'fmcg': 86,
#  'standard operating procedures': 86,
#  'customer engagement': 85,
#  'kubernetes': 85,
#  'brd': 85,
#  'production': 85,
#  'automotive': 84,
#  'employee engagement': 84,
#  'head business development': 84,
#  'software engineering': 83,
#  'costing': 83,
#  'market intelligence': 83,
#  'qa': 83,
#  'numpy': 82,
#  'pandas': 82,
#  'kafka': 82,
#  'information management': 82,
#  'pivot table': 81,
#  'selenium': 81,
#  'solution design': 81,
#  'database management': 80,
#  'graphics': 80,
#  'agile development': 80,
#  'performance testing': 80,
#  'bidding': 79,
#  'customer satisfaction': 79,
#  'perl': 79,
#  'model development': 78,
#  'logistic regression': 78,
#  'mentor': 78,
#  'digital media': 78,
#  'financial statements': 78,
#  'loans': 77,
#  'business transformation': 77,
#  'digital': 77,
#  'airflow': 76,
#  'warehouse': 76,
#  'automation testing': 76,
#  'technology': 76,
#  'intellectual property': 76,
#  'planning': 76,
#  'generative ai': 75,
#  'llm': 75,
#  'processing': 75,
#  'uml': 75,
#  'clinical research': 75,
#  'uat': 75,
#  'actuarial': 75,
#  'professional': 75,
#  'teaching': 75,
#  'continuous integration': 74,
#  'docker': 74,
#  'functional testing': 74,
#  'incident management': 74,
#  'saas': 74,
#  'genetics': 74,
#  'manager internal audit': 74,
#  'french': 74,
#  'dax': 74,
#  'hris': 74,
#  'service delivery': 74,
#  'business objects': 73,
#  'leadership development': 73,
#  'gis': 73,
#  'balance sheet': 73,
#  'business reporting': 73,
#  'project documentation': 73,
#  'clinical trials': 72,
#  'data architect': 72,
#  'configuration management': 72,
#  'service management': 72,
#  'leadership': 72,
#  'hypothesis testing': 71,
#  'data reporting': 71,
#  'sql database': 71,
#  'primary research': 71,
#  'quality control': 71,
#  'adobe analytics': 70,
#  'hrsd': 70,
#  'api': 70,
#  'senior management': 70,
#  'process optimization': 69,
#  'economics': 69,
#  'product quality': 69,
#  'conceptualization': 69,
#  'subject matter expert': 69,
#  'google': 69,
#  'business services': 68,
#  'data entry': 68,
#  'outbound': 68,
#  'architectural design': 67,
#  'research analysis': 67,
#  'quality standards': 67,
#  'design': 67,
#  'merchandising': 67,
#  'quality assurance': 67,
#  'cognos': 66,
#  'ssi': 66,
#  'inventory management': 66,
#  'google adwords': 66,
#  'logistics': 65,
#  'rest': 65,
#  'sr': 64,
#  'microsoft dynamics': 64,
#  'technology solutions': 64,
#  'system integration': 64,
#  'tds': 64,
#  'cloud services': 63,
#  'product marketing': 63,
#  'commerce': 63,
#  'program management': 63,
#  'cms': 63,
#  'quantitative research': 63,
#  'hibernate': 63,
#  'ai': 62,
#  'scm': 62,
#  'mis operations': 62,
#  'wireframing': 62,
#  'reinsurance': 62,
#  'predictive analytics': 61,
#  'master data management': 61,
#  'nutrition': 61,
#  'managed services': 61,
#  'application support': 61,
#  'competitor analysis': 61,
#  'stakeholder engagement': 61,
#  'marketing operations': 61,
#  'autocad': 61,
#  'cold calling': 61,
#  'trend analysis': 60,
#  'cassandra': 60,
#  'flex': 60,
#  'us healthcare': 60,
#  'corporate': 60,
#  'enterprise applications': 60,
#  'financial modelling': 60,
#  'program': 59,
#  'design development': 59,
#  'accounts reconciliation': 59,
#  'hospitality': 59,
#  'big data technologies': 58,
#  'business research': 58,
#  '': 58,
#  'capital market': 58,
#  'data pipeline': 58,
#  'instrumentation': 58,
#  'cost': 58,
#  'marketing strategy': 58,
#  'business rules': 57,
#  'mlops': 57,
#  'business operations': 57,
#  'plm': 57,
#  'data services': 57,
#  'contract management': 57,
#  'reporting tools': 57,
#  'b2b': 57,
#  'kpi': 57,
#  'econometrics': 57,
#  'hp data protector': 57,
#  'architect': 57,
#  'german': 57,
#  'testing tools': 57,
#  'silicon': 56,
#  'bloomberg': 56,
#  'process control': 56,
#  'relationship': 56,
#  'agile scrum': 55,
#  'market data': 55,
#  'teradata': 55,
#  'aiml': 55,
#  'system testing': 55,
#  'nltk': 55,
#  'quality management': 55,
#  'ticketing': 55,
#  'marketing analytics': 54,
#  'amazon redshift': 54,
#  'rfp': 54,
#  'fixed income': 54,
#  'remediation': 54,
#  'diagnostics': 54,
#  'test scripts': 54,
#  'competitive intelligence': 54,
#  'resource allocation': 54,
#  'marketing executive': 54,
#  'gen ai': 53,
#  'integration testing': 53,
#  'lms': 53,
#  'manual testing': 53,
#  'customer retention': 53,
#  'resource management': 53,
#  'quality audit': 53,
#  'text mining': 52,
#  'cad': 52,
#  'risk analytics': 52,
#  'digital transformation': 52,
#  'quality': 52,
#  'azure synapse': 52,
#  'application': 52,
#  'client management': 52,
#  'negotiation': 52,
#  'datastage': 51,
#  'translation': 51,
#  'cyber security': 51,
#  'computer': 51,
#  'aws sagemaker': 51,
#  'scalability': 51,
#  'photoshop': 51,
#  'operational support': 51,
#  'product strategy': 51,
#  'sql development': 50,
#  'keras': 50,
#  'data engineer': 50,
#  'mis preparation': 50,
#  'credit risk': 50,
#  'front office': 50,
#  'algorithm development': 50,
#  'service level': 50,
#  'manager program management': 50,
#  'tools': 50,
#  '.net': 50,
#  'azure cloud': 49,
#  'alteryx': 49,
#  'conditional formatting': 49,
#  'legal': 49,
#  'financial management': 49,
#  'senior business analyst': 49,
#  'internship': 49,
#  'frd': 49,
#  'it business analyst': 49,
#  'team building': 49,
#  'management skills': 49,
#  'performance': 49,
#  'control': 49,
#  'aml': 49,
#  'vendor': 49,
#  'customer analytics': 48,
#  'office': 48,
#  'management systems': 48,
#  'medical devices': 48,
#  'glue': 48,
#  'talent management': 48,
#  'technical lead': 48,
#  'microsoft applications': 48,
#  'analytical skill': 48,
#  'ssas': 48,
#  'big data analytics': 47,
#  'pattern recognition': 47,
#  'project development': 47,
#  'disaster recovery': 47,
#  'azure data lake': 47,
#  'sales analysis': 47,
#  'business process modeling': 47,
#  'shaping': 47,
#  'aws cloud': 46,
#  'etl process': 46,
#  'variance analysis': 46,
#  'core java': 46,
#  'supervision': 46,
#  'etl tool': 46,
#  'ci/cd': 46,
#  'jenkins': 46,
#  'electrical engineering': 46,
#  'software solutions': 46,
#  'link building': 46,
#  'media strategy': 46,
#  'technical documentation': 45,
#  'trade': 45,
#  'requirements': 45,
#  'industry research': 45,
#  'accounts payable': 45,
#  'wordpress': 45,
#  'database administration': 45,
#  'curriculum development': 45,
#  'statistical programming': 44,
#  'confluence': 44,
#  'ux': 44,
#  'secondary research': 44,
#  'wealth management': 44,
#  'maven': 44,
#  'investment management': 44,
#  'power query': 44,
#  'issue resolution': 44,
#  'business management': 44,
#  'content writing': 44,
#  'data integration': 44,
#  'product analyst': 44,
#  'insurance': 44,
#  'powershell': 44,
#  'hardware': 44,
#  'aviation': 43,
#  'demand forecasting': 43,
#  't-sql': 43,
#  'outsourcing': 43,
#  'order management': 43,
#  'research analyst': 43,
#  'regulatory compliance': 43,
#  'react.js': 43,
#  'technical design': 43,
#  'training and development': 43,
#  'sales planning': 43,
#  'mvc': 43,
#  'product launch': 43,
#  'team handling': 42,
#  'requirement analysis': 42,
#  'cro': 42,
#  'senior executive': 42,
#  'qualitative research': 42,
#  'reporting and analytics': 42,
#  'test management': 41,
#  'data transformation': 41,
#  'six sigma': 41,
#  'sap hana': 41,
#  'accounts receivable': 41,
#  'use cases': 41,
#  'factory': 41,
#  'demand planning': 41,
#  'sensors': 41,
#  'user research': 41,
#  'side': 41,
#  'soa': 41,
#  'test scenarios': 41,
#  'digital content': 41,
#  'b2b sales': 41,
#  'charts': 40,
#  'pricing': 40,
#  'ms office suite': 40,
#  'business process management': 40,
#  'db2': 40,
#  'subject matter expertise': 40,
#  'hr operations': 40,
#  'jsp': 40,
#  'coordination': 40,
#  'oops': 39,
#  'pharmaceutical': 39,
#  'team': 39,
#  'problem management': 39,
#  'inventory control': 39,
#  'automation tools': 39,
#  'inside sales': 39,
#  'patient care': 39,
#  'scripting': 39,
#  'proposal writing': 39,
#  'technical leadership': 39,
#  'content strategy': 39,
#  'semiconductor': 39,
#  'user interface designing': 39,
#  'campaigns': 39,
#  'predictive': 38,
#  'e-learning': 38,
#  'environmental science': 38,
#  'data lake': 38,
#  'rf': 38,
#  'client servicing': 38,
#  'formulas': 38,
#  'principal': 38,
#  'chemical': 38,
#  'hipaa': 38,
#  'sas programming': 37,
#  'sez': 37,
#  'purchase': 37,
#  'mis executive': 37,
#  'collections': 37,
#  'sales management': 37,
#  'executive': 37,
#  'kyc': 37,
#  'test planning': 37,
#  'tally': 37,
#  'licensing': 37,
#  'pipeline': 37,
#  'gen': 36,
#  'languages': 36,
#  'matrix': 36,
#  'operational risk': 36,
#  'conflict management': 36,
#  'client': 36,
#  'time series analysis': 36,
#  'azure devops': 36,
#  'test driven development': 36,
#  'enterprise architecture': 36,
#  'node.js': 36,
#  'application software': 36,
#  'server': 36,
#  'min': 36,
#  'lead business analyst': 36,
#  'business finance': 36,
#  'ml algorithms': 36,
#  'project implementation': 35,
#  'technical analysis': 35,
#  'transformers': 35,
#  'client interaction': 35,
#  'software development methodologies': 35,
#  'production planning': 35,
#  'pricing strategy': 35,
#  'sql azure': 35,
#  'data interpretation': 35,
#  'pharmacy': 35,
#  'team leading': 35,
#  'internal audit': 35,
#  'sales executive': 35,
#  'application design': 35,
#  'content marketing': 35,
#  'solr': 35,
#  'cnn': 34,
#  'sales forecasting': 34,
#  'supply chain operations': 34,
#  'business requirements': 34,
#  'siemens': 34,
#  'system': 34,
#  'microsoft office suite': 34,
#  'android': 34,
#  'angular': 34,
#  'business modeling': 34,
#  'aws glue': 34,
#  'business development executive': 34,
#  'stress testing': 34,
#  'pricing analysis': 34,
#  'web designing': 34,
#  'ms word': 34,
#  'counselling': 34,
#  'portfolio management': 34,
#  'virtualization': 34,
#  'full stack': 34,
#  'linear regression': 33,
#  'social networking': 33,
#  'product life cycle': 33,
#  'dns': 33,
#  'sap mm': 33,
#  'electronics': 33,
#  'it recruitment': 33,
#  'process documentation': 33,
#  'transition': 33,
#  'venture capital': 33,
#  'opencv': 33,
#  'ups': 33,
#  'digital analytics': 33,
#  'data warehousing concepts': 33,
#  'conflict resolution': 33,
#  'sow': 33,
#  'cost reduction': 33,
#  'presentation': 33,
#  'client coordination': 33,
#  'field sales': 33,
#  'sap bw': 33,
#  'quality improvement': 33,
#  'fabrication': 33,
#  'technology management': 32,
#  'google sheets': 32,
#  'vision': 32,
#  'mdm': 32,
#  'credit analysis': 32,
#  'master data': 32,
#  'performance optimization': 32,
#  'anti money laundering': 32,
#  'network security': 32,
#  'risk compliance': 32,
#  'powerapps': 32,
#  'logistics management': 32,
#  'strategy development': 32,
#  'growth strategy': 32,
#  'active directory': 32,
#  'writing': 32,
#  'process excellence': 32,
#  'campaign planning': 32,
#  'performance marketing': 32,
#  'customer complaints': 32,
#  'telecommunication': 31,
#  'data modelling': 31,
#  'senior data analyst': 31,
#  'data research': 31,
#  'signal processing': 31,
#  'engineering manager': 31,
#  'business process analysis': 31,
#  'etl testing': 31,
#  'business process improvement': 31,
#  'rpa': 31,
#  'investigation': 31,
#  'spanish': 31,
#  'spring boot': 31,
#  'product service': 31,
#  'generation': 31,
#  'civil': 31,
#  'leadership skills': 31,
#  'flask': 31,
#  'talend': 30,
#  'construction': 30,
#  'langchain': 30,
#  'aerospace': 30,
#  'bioinformatics': 30,
#  'tdd': 30,
#  'individual contributor': 30,
#  'illustrator': 30,
#  'aws lambda': 30,
#  'helpdesk': 30,
#  'waterfall': 30,
#  'event management': 30,
#  'sap erp': 30,
#  'legal compliance': 30,
#  'nbfc': 30,
#  'english': 30,
#  'chemistry': 30,
#  'abap': 30,
#  'electricals': 30,
#  'cmmi': 30,
#  'csr': 30,
#  'channel sales': 30,
#  'strategic partnerships': 30,
#  'object oriented design': 30,
#  'verbal communication': 29,
#  'analysts': 29,
#  'consultancy': 29,
#  'regression testing': 29,
#  'object oriented programming': 29,
#  'digital strategy': 29,
#  'wireless': 29,
#  'interpersonal': 29,
#  'visual studio': 29,
#  'integration': 29,
#  'inspection': 29,
#  'brand management': 29,
#  'informatica powercenter': 29,
#  'databricks': 29,
#  'information retrieval': 29,
#  'business executive': 29,
#  'calling': 29,
#  'support services': 29,
#  'client engagement': 29,
#  'warehouse management': 29,
#  'paas': 29,
#  'application security': 29,
#  'client relationship': 29,
#  'acquisition': 29,
#  'vertica': 29,
#  'marketing management': 29,
#  'query optimization': 28,
#  'powerbi': 28,
#  'investment': 28,
#  'assistant professor': 28,
#  'mechanical': 28,
#  'msbi': 28,
#  'access management': 28,
#  'global operations': 28,
#  'robotics': 28,
#  'human capital': 28,
#  'oracle sql': 28,
#  'financial analyst': 28,
#  'google ads': 28,
#  'product analysis': 28,
#  'workforce management': 28,
#  'nursing': 28,
#  'advisory': 28,
#  'microservices': 28,
#  'strategic sourcing': 28,
#  'budget management': 28,
#  'branding': 28,
#  'research associate': 28,
#  'sumif': 28,
#  'test strategy': 27,
#  'oncology': 27,
#  'formulation': 27,
#  'biotechnology': 27,
#  'release management': 27,
#  'ifrs': 27,
#  'content development': 27,
#  'power bi reports': 27,
#  'cash management': 27,
#  'content creation': 27,
#  'engineering design': 27,
#  'it operations': 26,
#  'intern': 26,
#  'trello': 26,
#  'ites': 26,
#  'development testing': 26,
#  'configuration': 26,
#  'japanese': 26,
#  'radiology': 26,
#  'qc': 26,
#  'web application': 26,
#  'process mapping': 26,
#  'cosmos': 26,
#  'peoplesoft': 26,
#  'sharepoint': 26,
#  'serv': 26,
#  'business excellence': 26,
#  'dax queries': 26,
#  'manufacturing process': 26,
#  'rfq': 26,
#  'compliance management': 26,
#  'user experience design': 26,
#  'client relationship management': 26,
#  'cma': 26,
#  'printing': 26,
#  'policies': 26,
#  'data profiling': 25,
#  'cloudera': 25,
#  'financial markets': 25,
#  'dashboard development': 25,
#  'hr analytics': 25,
#  'resourcing': 25,
#  'development manager': 25,
#  'director': 25,
#  'supply': 25,
#  'vb': 25,
#  'rca': 25,
#  'itil': 25,
#  'ruby': 25,
#  'deep learning frameworks': 25,
#  'sourcing': 25,
#  'content': 25,
#  'jdbc': 25,
#  'project coordination': 25,
#  'ms office tools': 25,
#  'product planning': 25,
#  'organizational development': 25,
#  'asp.net mvc': 25,
#  'category management': 25,
#  'software architecture': 25,
#  'interaction design': 25,
#  'azure machine learning': 24,
#  'bricks': 24,
#  'matplotlib': 24,
#  'application programming': 24,
#  'thermal': 24,
#  'ms excel': 24,
#  'mechanical engineering': 24,
#  'workforce planning': 24,
#  'graphic designing': 24,
#  'computer operating': 24,
#  'solution architect': 24,
#  'quality analysis': 24,
#  'erwin': 24,
#  'balance sheet analysis': 24,
#  'hr generalist activities': 24,
#  'api integration': 24,
#  'triggers': 24,
#  'visual basic': 24,
#  'unix shell scripting': 24,
#  'cash flow': 24,
#  'associate professor': 24,
#  'splunk': 24,
#  ...}
