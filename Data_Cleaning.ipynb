# %%
import pickle
import pandas as pd

# %%
with open("data", "rb") as fp:   # Unpickling
    data = pickle.load(fp)

# %%
df = pd.DataFrame(data, columns=["jobTitle","companyName","skills","jobDetailURL","jobDescription","salary","listingType","portal"])

# %%
df
# Out:
#                                                jobTitle  \
# 0                                      Insights Analyst
# 1                                    Analyst (Tracking)
# 2                                       Insight Analyst
# 3                                 Structuring Associate
# 4                                 Python Data Scientist
# ...                                                 ...
# 5017     Medical Sales Representative / Therapy Manager
# 5018  Urgent Hiring - Record Retrieval Specialist(sa...
# 5019          AR Caller - US Shift @ Ahmedabad -BPO/KPO
# 5020  Medical Representative- Veterinary Sales (Tabl...
# 5021             Medical Representative (MR) @Ahmedabad
#
#                 companyName  \
# 0            Forbes Advisor
# 1               Ormax Media
# 2                      Blis
# 3                    Nomura
# 4     Wizaltia Hr Solutions
# ...                     ...
# 5017     Bharat Parenterals
# 5018        Arise Solutions
# 5019        Arise Solutions
# 5020      The Indiajobs.com
# 5021                Ikamate
#
#                                                  skills  \
# 0     [data analysis, automation, google analytics, ...
# 1     [analytical skills, data analysis, excel, seni...
# 2     [data analysis, sales, senior analyst, agile, ...
# 3     [computer science, front office, agile, data q...
# 4     [computer science, analytical skills, data ana...
# ...                                                 ...
# 5017  [health care services, pharmaceutical, marketi...
# 5018  [international bpo, us process, fluent english...
# 5019  [international voice process, denial handling,...
# 5020  [veterinary sales, medicine, tablets, formulat...
# 5021  [mr, medical marketing, pharmaceutical sales, ...
#
#                                            jobDetailURL  \
# 0     https://www.naukri.com/job-listings-insights-a...
# 1     https://www.naukri.com/job-listings-analyst-tr...
# 2     https://www.naukri.com/job-listings-insight-an...
# 3     https://www.naukri.com/job-listings-structurin...
# 4     https://www.naukri.com/job-listings-python-dat...
# ...                                                 ...
# 5017  https://www.naukri.com/job-listings-medical-sa...
# 5018  https://www.naukri.com/job-listings-urgent-hir...
# 5019  https://www.naukri.com/job-listings-ar-caller-...
# 5020  https://www.naukri.com/job-listings-medical-re...
# 5021  https://www.naukri.com/job-listings-medical-re...
#
#                                          jobDescription             salary  \
# 0     Bachelors degree in Data Science,Statistics,Co...      Not disclosed
# 1     A keen interest in media content,a curious min...      Not disclosed
# 2     experience is a bonus,but this can be develope...      Not disclosed
# 3     CFA level I preferred<br><br>Experience <br><b...      Not disclosed
# 4     We are actively seeking talented Data Scientis...      Not disclosed
# ...                                                 ...                ...
# 5017  1 to 5 years of pharmaceutical sales experienc...     2.25-5 Lacs PA
# 5018  Retrieve records from various sources, coordin...  1.75-2.75 Lacs PA
# 5019  Hiring For AR Caller \n#Shift: US Shift\n#Sala...     1.25-3 Lacs PA
# 5020  Medical Representative- Veterinary Sales\nExpe...   50,000-3 Lacs PA
# 5021  We are Hiring for Medical Representative for R...      2-3.5 Lacs PA
#
#      listingType      portal
# 0            job  Naukri.com
# 1            job  Naukri.com
# 2            job  Naukri.com
# 3            job  Naukri.com
# 4            job  Naukri.com
# ...          ...         ...
# 5017         job  Naukri.com
# 5018         job  Naukri.com
# 5019         job  Naukri.com
# 5020         job  Naukri.com
# 5021         job  Naukri.com
#
# [5022 rows x 8 columns]

# %%
def convert_and_return_avg_in_lakhs(value):
# function that extract value from salary string and return the average in LPA

    
    try:
        #for range which has both thousands and lacks
        if ',' in value and ('Lac' in value or 'Lacs' in value):
            value = value.replace(',', '') #str
            value=value.split(" ")[0] #str
            value = value.split("-") #arr of str
            temp = 0
            for i in value:
                i=float(i)
                if i > 1000:
                    i=i/100000
                temp += float(i)
            value = temp/2
            return value 
        
        # for range which has only thousands
        elif ',' in value:
            
            value = value.replace(',', '') #str
            value=value.split(" ")[0] #str
            
            if "-" in value: 
                value = value.split("-") #arr of str
                temp = 0
                for i in value:
                    i=float(i)
                    i= i/100000
                    temp += i
                value = temp/2
                return value
            else:
                value = float(value)
                value = value/100000
                return value
        # values that has lacs and crores     
        elif 'Cr' in value and ('Lac' in value or 'Lacs' in value):
            value = value.replace(' Lacs', '').replace(' Lac', '').replace(' Cr', "")
            value = value.split(" ")[0]
            value = value.split("-")
            temp = 0
            for i in range(len(value)):
                value[i]=float(value[i])
                if i == 1:
                    value[i]=value[i]*100
                temp += value[i]
            value = temp/2
            return value
        # values that has range in crores
        elif 'Cr' in value:
            value=value.split(" ")[0] #str
            if "-" in value: 
                value = value.split("-") #arr of str
                temp = 0
                for i in value:
                    i=float(i)
                    i=i*100
                    temp += i
                value = temp/2
                return value
            else:
                value = float(value)
                return value
        # for lacs    
        elif 'Lac' in value or 'Lacs' in value:
            
            value=value.split(" ")[0] #str
            if "-" in value: 
                value = value.split("-") #arr of str
                temp = 0
                for i in value:
                    i=float(i)
                    temp += i
                value = temp/2
                return value
            else:
                value = float(value)
                return value
        else:
            return None
    except:
            return value

# %%
# creates a new column in the dataframe where it stores the average salary in lacks
df['Average Salary (Lacs PA)'] = df['salary'].apply(convert_and_return_avg_in_lakhs)

# %%
# it only consiters the numeric and replace rest with None and then it calculates the mean salary or average salary
average_salary = pd.to_numeric(df["Average Salary (Lacs PA)"], errors='coerce').mean()

# %%
average_salary
# Out:
# 5.51112828438949

# %%
#extracting skills
skills={}
def extracting_skills(value):
    arr = value
    for skill in arr:
        if skill in skills:
            skills[skill]+=1
        else:
            skills[skill]=1

# %%
df["skills"].apply(extracting_skills)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 5017    None
# 5018    None
# 5019    None
# 5020    None
# 5021    None
# Name: skills, Length: 5022, dtype: object

# %%
#sorting the skill dictionary in decresing order to frequency of the skills
sorted_skills = dict(sorted(skills.items(), key=lambda item: item[1], reverse=True))

# %%
sorted_skills
# Out:
# {'computer science': 569,
#  'javascript': 458,
#  'management': 392,
#  'analytical': 374,
#  'html': 342,
#  'sales': 317,
#  'data analysis': 267,
#  'coding': 251,
#  'front end': 247,
#  'project management': 240,
#  'healthcare': 234,
#  'troubleshooting': 224,
#  'mysql': 216,
#  'information technology': 201,
#  'agile': 200,
#  'sql': 197,
#  'jquery': 182,
#  'php': 180,
#  'training': 175,
#  'research': 174,
#  'pharma': 174,
#  'development': 174,
#  'automation': 173,
#  'python': 170,
#  'debugging': 160,
#  'consulting': 154,
#  'manager technology': 148,
#  'git': 143,
#  'machine learning': 138,
#  'linux': 138,
#  'nursing': 138,
#  'manager quality assurance': 137,
#  'medical': 135,
#  'networking': 128,
#  'analytics': 127,
#  'css': 127,
#  'business analysis': 126,
#  'backend': 126,
#  'web development': 126,
#  'data management': 123,
#  'c++': 123,
#  'business analyst': 123,
#  'monitoring': 121,
#  'excel': 118,
#  'programming': 112,
#  'sap': 110,
#  'pharmaceutical': 109,
#  'web technologies': 109,
#  'interpersonal skills': 105,
#  'administration': 104,
#  'operations': 104,
#  'customer service': 104,
#  'business development': 103,
#  'windows': 100,
#  'patient care': 99,
#  'analytical skills': 96,
#  'xml': 93,
#  'software testing': 90,
#  'compliance': 89,
#  'application development': 88,
#  'microsoft': 84,
#  'teaching': 82,
#  'oracle': 80,
#  'pdf': 80,
#  'marketing': 80,
#  'version control': 80,
#  'technical support': 78,
#  'usage': 77,
#  'market research': 75,
#  'product management': 75,
#  'ms office': 75,
#  'testing': 74,
#  'science': 74,
#  'communication skills': 74,
#  'mis': 73,
#  'social media': 73,
#  'json': 71,
#  'unit testing': 70,
#  'software': 69,
#  'wordpress': 69,
#  'data structures': 68,
#  'c': 68,
#  'mvc': 67,
#  'medicine': 67,
#  'hr': 66,
#  'risk management': 66,
#  'documentation': 65,
#  'pharmacy': 65,
#  'packaging': 65,
#  'data analytics': 64,
#  'erp': 64,
#  'critical care': 64,
#  'data science': 63,
#  'artificial intelligence': 61,
#  'diagnostics': 60,
#  'dnb': 60,
#  'data': 59,
#  'software design': 59,
#  'time management': 59,
#  'architecture': 58,
#  'power bi': 57,
#  'performance tuning': 57,
#  'microbiology': 57,
#  'chemical': 56,
#  'postgresql': 55,
#  'asset management': 54,
#  'c#': 54,
#  'test cases': 54,
#  'life sciences': 54,
#  'gnm': 54,
#  'data quality': 53,
#  'data visualization': 53,
#  'database design': 53,
#  'manager quality control': 52,
#  'data collection': 52,
#  'software development': 52,
#  'chemistry': 52,
#  'gcp': 51,
#  'financial services': 51,
#  'icu': 51,
#  'data modeling': 50,
#  'java': 50,
#  'software development life cycle': 49,
#  'supply chain': 48,
#  'analysis': 48,
#  'assistance': 48,
#  'senior': 48,
#  'cloud': 47,
#  'database': 46,
#  'unix': 46,
#  'technical': 46,
#  'accounting': 46,
#  'finance': 46,
#  'web services': 45,
#  'recruitment': 45,
#  'computer': 45,
#  'ms sql': 45,
#  'supervision': 44,
#  'production': 44,
#  'cms': 43,
#  'nosql': 43,
#  'doctor': 43,
#  'open source': 43,
#  'quality control': 43,
#  'pharmaceutical sales': 43,
#  'data analyst': 43,
#  'data mining': 42,
#  'basic': 42,
#  'customer support': 42,
#  'lead generation': 42,
#  'medical representative': 42,
#  'iso': 42,
#  'http': 41,
#  'mathematics': 41,
#  'team management': 41,
#  'seo': 41,
#  'data processing': 40,
#  'biotechnology': 40,
#  'medical sales': 40,
#  'jira': 40,
#  'banking': 40,
#  'selenium': 40,
#  'scrum': 39,
#  'graphics': 39,
#  'google analytics': 38,
#  'workflow': 38,
#  'business intelligence': 38,
#  'pharma selling': 38,
#  'clinical': 38,
#  'investment banking': 37,
#  'process improvement': 37,
#  'customer relationship': 37,
#  'crm': 36,
#  'aws': 36,
#  'testing tools': 36,
#  'presentation skills': 36,
#  'purchase': 36,
#  'staff nurse': 36,
#  'change management': 35,
#  'natural language processing': 35,
#  'mongodb': 35,
#  'budgeting': 35,
#  'lab': 35,
#  'sas': 34,
#  'digital marketing': 34,
#  'information security': 34,
#  'focus': 34,
#  'mr': 34,
#  'react.js': 34,
#  'sr': 34,
#  'perl': 34,
#  'web designing': 34,
#  'opd': 34,
#  'photoshop': 34,
#  'procurement': 34,
#  'business analytics': 33,
#  'publishing': 33,
#  'billing': 33,
#  'continuous improvement': 33,
#  'gmp': 33,
#  'design': 33,
#  'deployment': 32,
#  'html5': 32,
#  'corporate': 32,
#  'radiology': 32,
#  'deep learning': 31,
#  'asp.net': 31,
#  'nutrition': 31,
#  'business planning': 31,
#  'mobile applications': 31,
#  'tableau': 30,
#  'health insurance': 30,
#  'electronics': 30,
#  'mbbs': 30,
#  'surgical': 30,
#  'illustrator': 30,
#  'rest': 29,
#  'senior executive': 29,
#  'cold calling': 29,
#  'hospital': 29,
#  'vendor management': 29,
#  'qa': 29,
#  'hibernate': 29,
#  'e-commerce': 29,
#  'microsoft azure': 28,
#  'stored procedures': 28,
#  'health care services': 28,
#  'data warehousing': 28,
#  'android': 28,
#  'cme': 28,
#  'clinical research': 28,
#  'auditing': 28,
#  'b2b sales': 28,
#  'active directory': 28,
#  'emergency medicine': 28,
#  'pediatrics': 28,
#  'scheduling': 27,
#  'quality': 27,
#  'quality assurance': 27,
#  'mobile development': 27,
#  'sales strategy': 27,
#  'pharma marketing': 27,
#  'us healthcare': 27,
#  'counselling': 27,
#  'pathology': 27,
#  'hplc': 26,
#  'github': 26,
#  'sdlc': 26,
#  'qc': 26,
#  'therapy': 26,
#  'engineering': 26,
#  'autocad': 26,
#  'standard operating procedures': 26,
#  'pharmacovigilance': 26,
#  'field sales': 26,
#  'sql server': 26,
#  'ios': 26,
#  'server': 25,
#  'regulatory affairs': 25,
#  'formulation': 25,
#  'sales executive': 25,
#  'san': 25,
#  'django': 25,
#  'regression testing': 25,
#  'powerpoint': 24,
#  'risk assessment': 24,
#  'agile methodology': 24,
#  'big data': 24,
#  'raw material': 24,
#  'dermatology': 24,
#  'quality improvement': 24,
#  'manual testing': 24,
#  '.net': 24,
#  'clinical trials': 24,
#  'product launch': 24,
#  'claims': 24,
#  'glp': 24,
#  'instrumentation': 24,
#  'brand management': 24,
#  'front office': 23,
#  'forecasting': 23,
#  'head business development': 23,
#  'financial analysis': 23,
#  'oncology': 23,
#  'apache': 23,
#  'cloud computing': 23,
#  'devops': 23,
#  'technology': 23,
#  'advanced excel': 23,
#  'api': 23,
#  'medical rep': 23,
#  'selling': 23,
#  'content writing': 23,
#  'network security': 23,
#  'customer satisfaction': 23,
#  'marketing executive': 23,
#  'automation testing': 23,
#  'content management': 23,
#  'ups': 23,
#  'biomedical': 23,
#  'medical insurance': 22,
#  'problem solving': 22,
#  'production support': 22,
#  'continuous integration': 22,
#  'ruby': 22,
#  'sales operations': 22,
#  'regulatory': 22,
#  'environmental science': 22,
#  'executive': 22,
#  'relationship': 22,
#  'surgery': 22,
#  'account management': 22,
#  'user interface designing': 22,
#  'supervisor': 22,
#  'nicu': 22,
#  'animation': 21,
#  'computer vision': 21,
#  'plsql': 21,
#  'statistics': 21,
#  'process': 21,
#  'technical documentation': 21,
#  'reconciliation': 21,
#  'biology': 21,
#  'hiring': 21,
#  'technical writing': 21,
#  'nursing staff': 21,
#  'nurse': 21,
#  'user acceptance testing': 21,
#  'physiotherapy': 21,
#  'management consulting': 20,
#  'image processing': 20,
#  'mentor': 20,
#  'rdbms': 20,
#  'dns': 20,
#  'maven': 20,
#  'business solutions': 20,
#  'strategic planning': 20,
#  'application support': 20,
#  'algorithms': 20,
#  'coordination': 20,
#  'biochemistry': 20,
#  'back office': 20,
#  'emergency': 20,
#  'social science': 20,
#  'medical billing': 20,
#  'anesthesia': 20,
#  'wellness': 20,
#  'medical records': 20,
#  'ticketing': 20,
#  'android sdk': 20,
#  'senior analyst': 19,
#  'hp data protector': 19,
#  'code': 19,
#  'jsp': 19,
#  'ccna': 19,
#  'customer management': 19,
#  'presales': 19,
#  'diversity and inclusion': 19,
#  'reporting': 19,
#  'mis reporting': 19,
#  'business administration': 19,
#  'commerce': 19,
#  'soa': 19,
#  'medical devices': 19,
#  'business process': 19,
#  'side': 19,
#  'wealth management': 19,
#  'market intelligence': 19,
#  'cardiovascular': 19,
#  'sem': 18,
#  'object oriented design': 18,
#  'payroll': 18,
#  'test scripts': 18,
#  'it services': 18,
#  'gap analysis': 18,
#  'prototype': 18,
#  'performance management': 18,
#  'configuration management': 18,
#  'cardiology': 18,
#  'regulatory compliance': 18,
#  'talent acquisition': 18,
#  'medical affairs': 18,
#  'project': 18,
#  'due diligence': 18,
#  'agile development': 18,
#  'healthcare sales': 18,
#  'corporate sales': 18,
#  'soc': 18,
#  'translation': 18,
#  'english': 18,
#  'office': 18,
#  'french': 18,
#  'query': 18,
#  'ehs': 18,
#  'channel sales': 18,
#  'analyst': 18,
#  'logistics': 18,
#  'business development executive': 18,
#  'help desk': 18,
#  'access controls': 18,
#  'telephony support': 18,
#  'information': 18,
#  'uml': 18,
#  'bpo': 17,
#  'cro': 17,
#  'neural networks': 17,
#  'tutoring': 17,
#  'r': 17,
#  'operations management': 17,
#  'sales management': 17,
#  'inventory management': 17,
#  'hrsd': 17,
#  'software engineering': 17,
#  'market analysis': 17,
#  'data validation': 17,
#  'spss': 17,
#  'data governance': 17,
#  'preventive maintenance': 17,
#  'internal medicine': 17,
#  'business executive': 17,
#  'data cleansing': 17,
#  'ot': 17,
#  'ajax': 16,
#  'report writing': 16,
#  'bi': 16,
#  'bfsi': 16,
#  'negotiation': 16,
#  'staffing': 16,
#  'project planning': 16,
#  'shell scripting': 16,
#  'application': 16,
#  'sales head': 16,
#  'cvs': 16,
#  'quality standards': 16,
#  'sales and marketing': 16,
#  'tally': 16,
#  'vendor': 16,
#  'sales executive activities': 16,
#  'dbms': 16,
#  'rmo': 16,
#  'gynecology': 16,
#  'tpa': 16,
#  'data integrity': 16,
#  'health': 16,
#  'hardware': 16,
#  'manual': 16,
#  'performance testing': 16,
#  'legal': 16,
#  'fmcg': 15,
#  'assurance': 15,
#  'software development methodologies': 15,
#  'marketing campaigns': 15,
#  'retail': 15,
#  'telecom': 15,
#  'report generation': 15,
#  'relationship management': 15,
#  'stakeholder management': 15,
#  'optometry': 15,
#  'contracts': 15,
#  'method validation': 15,
#  'ophthalmology': 15,
#  'investigation': 15,
#  'international': 15,
#  'bootstrap': 15,
#  'clinical data management': 15,
#  'revenue cycle management': 15,
#  'core java': 15,
#  'medical services': 15,
#  'manager internal audit': 15,
#  'data entry': 15,
#  'quality management': 15,
#  'lan': 15,
#  'technical product configuration': 15,
#  'integration php': 15,
#  '': 15,
#  'email marketing': 15,
#  'qlikview': 14,
#  'macros': 14,
#  'simulation': 14,
#  'dispensing': 14,
#  'wan': 14,
#  'equity': 14,
#  'electrical engineering': 14,
#  'operating': 14,
#  'field': 14,
#  'infrastructure': 14,
#  'corporate governance': 14,
#  'iss': 14,
#  'it sales': 14,
#  'maintenance': 14,
#  'outbound': 14,
#  'control': 14,
#  'veterinary': 14,
#  'inventory control': 14,
#  'informatica': 14,
#  'operation theatre': 14,
#  'lab testing': 14,
#  'it': 14,
#  'helpdesk': 14,
#  'csr': 14,
#  'functional testing': 14,
#  'orthopedics': 14,
#  'pain management': 14,
#  'iis': 14,
#  'fixed income': 14,
#  'mvvm': 14,
#  'salesforce': 13,
#  'software quality': 13,
#  'matlab': 13,
#  'tdd': 13,
#  'application programming': 13,
#  'planning': 13,
#  'node.js': 13,
#  'general': 13,
#  'data security': 13,
#  'product design': 13,
#  'drupal': 13,
#  'vlookup': 13,
#  'equipment': 13,
#  'tgt': 13,
#  'bed': 13,
#  'production planning': 13,
#  'sql queries': 13,
#  'construction': 13,
#  'new product development': 13,
#  'anaesthesiologist': 13,
#  'b2b': 13,
#  'mri': 13,
#  'x-ray': 13,
#  'general medicine': 13,
#  'visual studio': 13,
#  'costing': 13,
#  'interpersonal': 13,
#  'formulation development': 13,
#  'inventory': 13,
#  'medical coding': 13,
#  'incident management': 13,
#  'sales process': 13,
#  'scalability': 13,
#  'research associate': 13,
#  'investment management': 13,
#  'graphic designing': 13,
#  'bidding': 13,
#  'data migration': 13,
#  'system architecture': 13,
#  'dom': 13,
#  'internet marketing': 13,
#  'advanced analytics': 12,
#  'system design': 12,
#  'application software': 12,
#  'customer experience': 12,
#  'information management': 12,
#  'azure': 12,
#  'hr executive': 12,
#  'test driven development': 12,
#  'hvac': 12,
#  'financial reporting': 12,
#  'configuration': 12,
#  'product service': 12,
#  'mechanical': 12,
#  'data engineering': 12,
#  'office administration': 12,
#  'customer engagement': 12,
#  'literature': 12,
#  'research and development': 12,
#  'business development management': 12,
#  'business strategy': 12,
#  'test management': 12,
#  'management systems': 12,
#  'warehouse': 12,
#  'international marketing': 12,
#  'email': 12,
#  'cad': 12,
#  'medical writing': 12,
#  'financial planning': 12,
#  'program': 12,
#  'interpersonal skill': 12,
#  'nabl': 12,
#  'product quality': 12,
#  'electricals': 12,
#  'social media marketing': 12,
#  'hospital administration': 12,
#  'relationship building': 12,
#  'ms word': 12,
#  'mlt': 12,
#  'metadata': 12,
#  'business research': 12,
#  'team': 12,
#  'application design': 12,
#  'ayurveda': 12,
#  'web application': 12,
#  'root cause analysis': 12,
#  'techno-commercial': 12,
#  'web': 12,
#  'mobile': 12,
#  'fresher': 12,
#  'advertising': 11,
#  'development testing': 11,
#  'manufacturing': 11,
#  'underwriting': 11,
#  'data manipulation': 11,
#  'chemical engineering': 11,
#  'hospitality': 11,
#  'database administration': 11,
#  'powershell': 11,
#  'disaster recovery': 11,
#  'business management': 11,
#  'gc': 11,
#  'molecular biology': 11,
#  'management skills': 11,
#  'statistical analysis': 11,
#  'office assistance': 11,
#  'sqlite': 11,
#  'senior management': 11,
#  'sales support': 11,
#  'saas': 11,
#  'typescript': 11,
#  'adobe': 11,
#  'vpn': 11,
#  'plc': 11,
#  'web application development': 11,
#  'financial statements': 11,
#  'operating systems': 11,
#  'integration testing': 11,
#  'software solutions': 11,
#  'spring boot': 11,
#  'vmware': 11,
#  'insurance': 11,
#  'actuarial': 11,
#  'neurology': 11,
#  'database management': 11,
#  'analytical instruments': 11,
#  'export documentation': 11,
#  'phlebotomy': 11,
#  'bloomberg': 11,
#  'data extraction': 11,
#  'quality audit': 11,
#  'taxation': 11,
#  'operational support': 11,
#  'dentistry': 11,
#  'housekeeping': 11,
#  'technical design': 11,
#  'cs': 11,
#  'inside sales': 11,
#  'creative writing': 11,
#  'it management': 11,
#  'waste water treatment': 11,
#  'technical sales': 11,
#  'j2ee': 11,
#  'cardiac': 11,
#  'ar calling': 11,
#  'web analytics': 11,
#  'ux': 11,
#  'blood bank': 11,
#  'online marketing': 11,
#  'swift': 11,
#  'css3': 11,
#  'water treatment': 11,
#  'cost': 11,
#  'business rules': 10,
#  'loans': 10,
#  'oops': 10,
#  'distribution system': 10,
#  'gis': 10,
#  'matrix': 10,
#  'sql database': 10,
#  'qms': 10,
#  'problem management': 10,
#  'docker': 10,
#  'technology solutions': 10,
#  'supply chain management': 10,
#  'echo': 10,
#  'android studio': 10,
#  'printing': 10,
#  'dms': 10,
#  'cosmetics': 10,
#  'requirement gathering': 10,
#  'sales coordination': 10,
#  'tools': 10,
#  'operational excellence': 10,
#  'environment': 10,
#  'ivf': 10,
#  'visio': 10,
#  'capital market': 10,
#  'technology management': 10,
#  'siem': 10,
#  'linq': 10,
#  'scala': 10,
#  'vendor development': 10,
#  'mdt': 10,
#  'tds': 10,
#  'cmo': 10,
#  'hr generalist activities': 10,
#  'employee engagement': 10,
#  'bsc': 10,
#  'scm': 10,
#  'stores': 10,
#  'training and development': 10,
#  'business operations': 10,
#  'ecg': 10,
#  'verbal communication': 10,
#  'organic chemistry': 10,
#  'network administration': 10,
#  'eclipse': 10,
#  'cisa': 10,
#  'ipqa': 10,
#  'ssrs': 10,
#  'bulk drugs': 10,
#  'intensive care': 10,
#  'business transformation': 10,
#  'computer hardware': 10,
#  'orchestration': 10,
#  'business requirements': 10,
#  'trend analysis': 10,
#  'wcf': 10,
#  'developing': 10,
#  'schema': 10,
#  'distributors': 10,
#  'customer profiling': 10,
#  'neonatology': 10,
#  'hr operations': 9,
#  'processing': 9,
#  'market data': 9,
#  'subject matter expert': 9,
#  'cyber security': 9,
#  'security operations': 9,
#  'software services': 9,
#  'release management': 9,
#  'system testing': 9,
#  'ci/cd': 9,
#  'marketing management': 9,
#  'computer operating': 9,
#  'receptionist activities': 9,
#  'portfolio management': 9,
#  'customer complaints': 9,
#  'pharmacology': 9,
#  'retail sales': 9,
#  'content': 9,
#  'writing': 9,
#  'international voice process': 9,
#  'php development': 9,
#  'service engineering': 9,
#  'generation': 9,
#  'area sales': 9,
#  'vb.net': 9,
#  '3d': 9,
#  'marketing strategy': 9,
#  'product development': 9,
#  'contract management': 9,
#  'content editing': 9,
#  'mechanical engineering': 9,
#  'professor activities': 9,
#  'german': 9,
#  'multithreading': 9,
#  'international business development': 9,
#  'master data management': 9,
#  'business services': 9,
#  'casualty': 9,
#  'ct': 9,
#  'front': 9,
#  'sales officer': 9,
#  'export': 9,
#  'insurance claims': 9,
#  'nabh': 9,
#  'quality systems': 9,
#  'design development': 9,
#  'collections': 9,
#  'pharmacist': 9,
#  'remediation': 9,
#  'diagnosis': 9,
#  'min': 9,
#  'production management': 9,
#  'full stack': 9,
#  'intellectual property': 9,
#  'ftp': 9,
#  'team building': 9,
#  'analytical chemistry': 9,
#  'conceptualization': 9,
#  'doctor activities': 9,
#  'waste management': 9,
#  'io': 9,
#  'consultancy': 9,
#  'hira': 9,
#  'infection control nurse': 9,
#  'environmental monitoring': 9,
#  'branding': 9,
#  'medical officer': 9,
#  'pharmaceutics': 9,
#  'legal compliance': 9,
#  'education': 9,
#  'clinical development': 9,
#  'ssis': 9,
#  'google adwords': 9,
#  'ios development': 9,
#  'jms': 9,
#  'struts': 9,
#  'pmp': 9,
#  'project implementation': 9,
#  'operations research': 8,
#  'statistical modeling': 8,
#  'financial markets': 8,
#  'spark': 8,
#  'quantitative research': 8,
#  'sociology': 8,
#  'external audit': 8,
#  'eye': 8,
#  'cash flow': 8,
#  'hipaa': 8,
#  'service level': 8,
#  'document management': 8,
#  'field marketing': 8,
#  'hive': 8,
#  'coordination skills': 8,
#  'dashboards': 8,
#  'medico marketing': 8,
#  'front desk': 8,
#  'transcription': 8,
#  'telesales': 8,
#  'bds': 8,
#  'system integration': 8,
#  'scaling': 8,
#  'calling': 8,
#  'project documentation': 8,
#  'project coordination': 8,
#  'ui/ux': 8,
#  'frontend development': 8,
#  'issue resolution': 8,
#  'proof reading': 8,
#  'telecalling': 8,
#  'asp': 8,
#  'radiography': 8,
#  'usg': 8,
#  'accounts receivable': 8,
#  'midwifery': 8,
#  'presentation': 8,
#  'career development': 8,
#  'uat': 8,
#  'payment collection': 8,
#  'obstetrics': 8,
#  'bhms': 8,
#  'bams': 8,
#  'ms': 8,
#  'office management': 8,
#  'theatre': 8,
#  'finished products': 8,
#  'content development': 8,
#  'spring': 8,
#  'synthesis': 8,
#  'infection control': 8,
#  'medical equipment': 8,
#  'key account management': 8,
#  'chemical analysis': 8,
#  'sms': 8,
#  'fact': 8,
#  'ui development': 8,
#  'sales planning': 8,
#  'oracle sql': 8,
#  'it support': 8,
#  'tcp': 8,
#  'telecommunication': 8,
#  'sdk': 8,
#  'osd': 8,
#  'genetics': 8,
#  'ultrasound': 8,
#  'stakeholder engagement': 8,
#  'architectural design': 8,
#  'accounts payable': 8,
#  'shop floor': 8,
#  'trade': 8,
#  'surgeon': 8,
#  'md': 8,
#  'solution architecture': 8,
#  'outsourcing': 8,
#  'gaming': 8,
#  'process automation': 8,
#  'voip': 8,
#  'access management': 8,
#  'security testing': 8,
#  'asp.net mvc': 8,
#  'microsoft dynamics': 8,
#  'aviation': 8,
#  'licensing': 8,
#  'cisco': 8,
#  'service': 8,
#  'fabrication': 8,
#  'haematology': 8,
#  'inspection': 8,
#  'wireframing': 8,
#  'equipment maintenance': 8,
#  'enterprise applications': 7,
#  'fluent english': 7,
#  'shaping': 7,
#  'cloud services': 7,
#  'project development': 7,
#  'kpi': 7,
#  'handling': 7,
#  'refraction': 7,
#  'system': 7,
#  'application architecture': 7,
#  'product engineering': 7,
#  'investment': 7,
#  'gastroenterology': 7,
#  'jenkins': 7,
#  'etl': 7,
#  'formulas': 7,
#  'it recruitment': 7,
#  'uv': 7,
#  'territory sales': 7,
#  'optometrists': 7,
#  'exercise': 7,
#  'meddra': 7,
#  'voice process': 7,
#  'angular': 7,
#  'web api': 7,
#  'rfid': 7,
#  'neuro': 7,
#  'vb': 7,
#  'order management': 7,
#  'flutter': 7,
#  'drug safety': 7,
#  'review': 7,
#  'data services': 7,
#  'direct sales': 7,
#  'audiology': 7,
#  'speech therapy': 7,
#  'requirements': 7,
#  'typing speed': 7,
#  'competitor analysis': 7,
#  'intelligence': 7,
#  'selling skills': 7,
#  'cell culture': 7,
#  'socket programming': 7,
#  'technical services': 7,
#  'framework': 7,
#  'international business': 7,
#  'design engineering': 7,
#  'team handling': 7,
#  'ortho': 7,
#  'product promotion': 7,
#  'lms': 7,
#  'convincing power': 7,
#  'gnm nursing': 7,
#  'obstetrics and gynaecology': 7,
#  'test scenarios': 7,
#  'end': 7,
#  'purchase management': 7,
#  'vba': 7,
#  'company': 7,
#  'skin care': 7,
#  'industrial sales': 7,
#  'drafting': 7,
#  'civil': 7,
#  'modeling': 7,
#  'visual design': 7,
#  'tomcat': 7,
#  'jsf': 7,
#  'object oriented programming': 7,
#  'merchandising': 7,
#  'python development': 7,
#  'food safety': 7,
#  'claims processing': 7,
#  'breakdown maintenance': 7,
#  'ra': 7,
#  'ui': 7,
#  'nephrology': 7,
#  'mpt': 7,
#  'cosmetology': 7,
#  'servicing': 7,
#  'global operations': 7,
#  'voice': 7,
#  'clinical operations': 7,
#  'intern': 7,
#  'room': 7,
#  'appium': 7,
#  'application security': 7,
#  'digital transformation': 7,
#  'nbfc': 7,
#  'sap abap': 7,
#  'counsellor': 7,
#  'research analyst': 7,
#  'remote desktop': 7,
#  'representative': 7,
#  'architect': 7,
#  'web design': 7,
#  'android application development': 7,
#  'ppc': 7,
#  'wpf': 7,
#  'media': 7,
#  'hris': 7,
#  'senior billing executive': 7,
#  'clinical associate': 7,
#  'dch': 7,
#  'epc': 6,
#  'brand awareness': 6,
#  'model development': 6,
#  'advisory': 6,
#  'machine learning algorithms': 6,
#  'econometrics': 6,
#  'time series analysis': 6,
#  'machine': 6,
#  ...}

# %%
df
# Out:
#                                                jobTitle  \
# 0                                      Insights Analyst
# 1                                    Analyst (Tracking)
# 2                                       Insight Analyst
# 3                                 Structuring Associate
# 4                                 Python Data Scientist
# ...                                                 ...
# 5017     Medical Sales Representative / Therapy Manager
# 5018  Urgent Hiring - Record Retrieval Specialist(sa...
# 5019          AR Caller - US Shift @ Ahmedabad -BPO/KPO
# 5020  Medical Representative- Veterinary Sales (Tabl...
# 5021             Medical Representative (MR) @Ahmedabad
#
#                 companyName  \
# 0            Forbes Advisor
# 1               Ormax Media
# 2                      Blis
# 3                    Nomura
# 4     Wizaltia Hr Solutions
# ...                     ...
# 5017     Bharat Parenterals
# 5018        Arise Solutions
# 5019        Arise Solutions
# 5020      The Indiajobs.com
# 5021                Ikamate
#
#                                                  skills  \
# 0     [data analysis, automation, google analytics, ...
# 1     [analytical skills, data analysis, excel, seni...
# 2     [data analysis, sales, senior analyst, agile, ...
# 3     [computer science, front office, agile, data q...
# 4     [computer science, analytical skills, data ana...
# ...                                                 ...
# 5017  [health care services, pharmaceutical, marketi...
# 5018  [international bpo, us process, fluent english...
# 5019  [international voice process, denial handling,...
# 5020  [veterinary sales, medicine, tablets, formulat...
# 5021  [mr, medical marketing, pharmaceutical sales, ...
#
#                                            jobDetailURL  \
# 0     https://www.naukri.com/job-listings-insights-a...
# 1     https://www.naukri.com/job-listings-analyst-tr...
# 2     https://www.naukri.com/job-listings-insight-an...
# 3     https://www.naukri.com/job-listings-structurin...
# 4     https://www.naukri.com/job-listings-python-dat...
# ...                                                 ...
# 5017  https://www.naukri.com/job-listings-medical-sa...
# 5018  https://www.naukri.com/job-listings-urgent-hir...
# 5019  https://www.naukri.com/job-listings-ar-caller-...
# 5020  https://www.naukri.com/job-listings-medical-re...
# 5021  https://www.naukri.com/job-listings-medical-re...
#
#                                          jobDescription             salary  \
# 0     Bachelors degree in Data Science,Statistics,Co...      Not disclosed
# 1     A keen interest in media content,a curious min...      Not disclosed
# 2     experience is a bonus,but this can be develope...      Not disclosed
# 3     CFA level I preferred<br><br>Experience <br><b...      Not disclosed
# 4     We are actively seeking talented Data Scientis...      Not disclosed
# ...                                                 ...                ...
# 5017  1 to 5 years of pharmaceutical sales experienc...     2.25-5 Lacs PA
# 5018  Retrieve records from various sources, coordin...  1.75-2.75 Lacs PA
# 5019  Hiring For AR Caller \n#Shift: US Shift\n#Sala...     1.25-3 Lacs PA
# 5020  Medical Representative- Veterinary Sales\nExpe...   50,000-3 Lacs PA
# 5021  We are Hiring for Medical Representative for R...      2-3.5 Lacs PA
#
#      listingType      portal  Average Salary (Lacs PA)
# 0            job  Naukri.com                       NaN
# 1            job  Naukri.com                       NaN
# 2            job  Naukri.com                       NaN
# 3            job  Naukri.com                       NaN
# 4            job  Naukri.com                       NaN
# ...          ...         ...                       ...
# 5017         job  Naukri.com                     3.625
# 5018         job  Naukri.com                     2.250
# 5019         job  Naukri.com                     2.125
# 5020         job  Naukri.com                     1.750
# 5021         job  Naukri.com                     2.750
#
# [5022 rows x 9 columns]
